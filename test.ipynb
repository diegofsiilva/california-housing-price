# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk

# %%
data = pd.read_csv('housing.csv')
print(data.dropna(inplace=True)) ## quando eu coloco o dropna ele vai retirar todas as linhas 
## que contenham pelo menos um valor "non-value"

## o inplace=true ele mudar o dataframe original tirando todos valores non mas não vai fazer uma copia do anterior
data.info()
print("-------------------------------------")
# Out:
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB
# -------------------------------------

# %%
from sklearn.model_selection import train_test_split ## aqui está sendo importada a função train and test da lib sklearn
x = data.drop(['median_house_value'], axis=1) ## aqui estou criando uma variavel x que 
## vai armazenar a coluna median house value, no caso, vou armazenar e apagar ela 
## E O AXIS FALA PARA O PANDAS QUE VOCE QUER REMOVE UMA COLUNA AXIS=1 E NÃO UMA LINHA AXIS=0
y = data['median_house_value']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2) ## aqui está sendo definido sendo definido
## as variaveis p/ teste e estou faladno que 20% dos dados vai ser pra teste
## se eu colocar um test size muito grande, o modelo pode ficar muito generalista
x_test.shape
train_data = x_train.join(y_train)
print(train_data)
print(train_data.hist(figsize=(8, 15)))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3251     -119.80     36.02                20.0        156.0            39.0
# 1550     -121.93     37.74                16.0       3326.0           419.0
# 4783     -118.33     34.03                39.0       2840.0           826.0
# 1330     -121.88     38.01                 9.0       5329.0          1284.0
# 6015     -117.79     34.07                34.0        975.0           192.0
# ...          ...       ...                 ...          ...             ...
# 2801     -119.02     35.42                42.0       2271.0           458.0
# 20278    -119.20     34.19                19.0       9503.0          1769.0
# 5331     -118.46     34.04                19.0       3522.0          1036.0
# 20160    -119.31     34.38                23.0        282.0            69.0
# 7793     -118.08     33.89                35.0       1071.0           290.0
#
# ...

# %%
print("Is train_data defined?", 'train_data' in globals())
# Out:
# Is train_data defined? True
